# %% [markdown]
# <a href="https://colab.research.google.com/github/shahpriyanka26/shahpriyanka26/blob/main/Evalml_Leadscoring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install evalml
# Out:
# Requirement already satisfied: evalml in /usr/local/lib/python3.7/dist-packages (0.43.0)
# Requirement already satisfied: lime>=0.2.0.1 in /usr/local/lib/python3.7/dist-packages (from evalml) (0.2.0.1)
# Requirement already satisfied: requirements-parser>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (0.5.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (1.21.5)
# Requirement already satisfied: sktime>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (0.11.0)
# Requirement already satisfied: colorama>=0.4.4 in /usr/local/lib/python3.7/dist-packages (from evalml) (0.4.4)
# Requirement already satisfied: seaborn>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from evalml) (0.11.2)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (2.0.0)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (1.7.3)
# Requirement already satisfied: woodwork>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (0.15.0)
# Requirement already satisfied: dask>=2021.10.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (2022.2.0)
# Requirement already satisfied: statsmodels>=0.12.2 in /usr/local/lib/python3.7/dist-packages (from evalml) (0.13.2)
# Requirement already satisfied: pyzmq>=20.0.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (22.3.0)
# Requirement already satisfied: matplotlib>=3.3.3 in /usr/local/lib/python3.7/dist-packages (from evalml) (3.5.1)
# Requirement already satisfied: shap>=0.36.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (0.40.0)
# Requirement already satisfied: category-encoders>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from evalml) (2.4.0)
# Requirement already satisfied: pmdarima>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from evalml) (1.8.5)
# Requirement already satisfied: graphviz>=0.13 in /usr/local/lib/python3.7/dist-packages (from evalml) (0.19.1)
# Requirement already satisfied: kaleido>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (0.2.1)
# Requirement already satisfied: nlp-primitives>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (2.5.0)
# Requirement already satisfied: vowpalwabbit>=8.11.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (9.1.0)
# Requirement already satisfied: scikit-optimize>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from evalml) (0.9.0)
# Requirement already satisfied: catboost>=0.20 in /usr/local/lib/python3.7/dist-packages (from evalml) (1.0.5)
# Requirement already satisfied: networkx<2.6,>=2.5 in /usr/local/lib/python3.7/dist-packages (from evalml) (2.5.1)
# Requirement already satisfied: imbalanced-learn>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (0.8.1)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from evalml) (1.6.4)
# Requirement already satisfied: pandas<1.4.0,>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (1.0.2)
# Requirement already satisfied: xgboost>=1.4.2 in /usr/local/lib/python3.7/dist-packages (from evalml) (1.5.2)
# Requirement already satisfied: ipywidgets>=7.5 in /usr/local/lib/python3.7/dist-packages (from evalml) (7.7.0)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (5.5.0)
# Requirement already satisfied: featuretools>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from evalml) (1.8.0)
# Requirement already satisfied: lightgbm>=2.3.1 in /usr/local/lib/python3.7/dist-packages (from evalml) (3.3.2)
# Requirement already satisfied: click>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from evalml) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from catboost>=0.20->evalml) (1.15.0)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category-encoders>=2.2.2->evalml) (0.5.2)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.10.0->evalml) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.10.0->evalml) (21.3)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.10.0->evalml) (2022.3.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.10.0->evalml) (0.11.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.10.0->evalml) (6.0)
# Requirement already satisfied: tqdm>=4.32.0 in /usr/local/lib/python3.7/dist-packages (from featuretools>=1.2.0->evalml) (4.63.0)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.7/dist-packages (from featuretools>=1.2.0->evalml) (5.9.0)
# Requirement already satisfied: distributed>=2021.10.0 in /usr/local/lib/python3.7/dist-packages (from featuretools>=1.2.0->evalml) (2022.2.0)
# Requirement already satisfied: holidays>=0.13 in /usr/local/lib/python3.7/dist-packages (from featuretools>=1.2.0->evalml) (0.13)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.10.0->featuretools>=1.2.0->evalml) (1.0.3)
# Requirement already satisfied: tornado>=5 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.10.0->featuretools>=1.2.0->evalml) (5.1.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.10.0->featuretools>=1.2.0->evalml) (2.11.3)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.10.0->featuretools>=1.2.0->evalml) (2.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.10.0->featuretools>=1.2.0->evalml) (57.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.10.0->featuretools>=1.2.0->evalml) (1.7.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.10.0->featuretools>=1.2.0->evalml) (2.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from holidays>=0.13->featuretools>=1.2.0->evalml) (2.8.2)
# Requirement already satisfied: convertdate>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from holidays>=0.13->featuretools>=1.2.0->evalml) (2.4.0)
# Requirement already satisfied: hijri-converter in /usr/local/lib/python3.7/dist-packages (from holidays>=0.13->featuretools>=1.2.0->evalml) (2.2.3)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.7/dist-packages (from holidays>=0.13->featuretools>=1.2.0->evalml) (0.2.1)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.7/dist-packages (from convertdate>=2.3.0->holidays>=0.13->featuretools>=1.2.0->evalml) (0.5.11)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn>=0.8.0->evalml) (1.1.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->evalml) (5.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->evalml) (5.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->evalml) (4.10.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->evalml) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->evalml) (5.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->evalml) (1.1.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->evalml) (3.6.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->evalml) (5.3.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->evalml) (0.8.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->evalml) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->evalml) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->evalml) (1.0.18)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->evalml) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->evalml) (0.7.5)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm>=2.3.1->evalml) (0.37.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.7/dist-packages (from lime>=0.2.0.1->evalml) (0.18.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->evalml) (1.4.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->evalml) (7.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->evalml) (4.31.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->evalml) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->evalml) (3.0.7)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.3->evalml) (3.10.0.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.5->evalml) (4.3.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.5->evalml) (4.9.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5->evalml) (21.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5->evalml) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5->evalml) (0.18.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5->evalml) (4.11.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5->evalml) (3.7.0)
# Requirement already satisfied: nltk>=3.4.5 in /usr/local/lib/python3.7/dist-packages (from nlp-primitives>=2.1.0->evalml) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.5->nlp-primitives>=2.1.0->evalml) (2022.3.15)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<1.4.0,>=1.3.0->evalml) (2018.9)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask>=2021.10.0->evalml) (0.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=5.0.0->evalml) (8.0.1)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima>=1.8.1->evalml) (0.29.28)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima>=1.8.1->evalml) (1.24.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets>=7.5->evalml) (0.2.5)
# Requirement already satisfied: types-setuptools>=57.0.0 in /usr/local/lib/python3.7/dist-packages (from requirements-parser>=0.2.0->evalml) (57.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.12->lime>=0.2.0.1->evalml) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.12->lime>=0.2.0.1->evalml) (2021.11.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.12->lime>=0.2.0.1->evalml) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.0->evalml) (3.1.0)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize>=0.8.1->evalml) (21.10.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap>=0.36.0->evalml) (0.55.1)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.7/dist-packages (from shap>=0.36.0->evalml) (0.0.7)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.7/dist-packages (from sktime>=0.7.0->evalml) (1.2.13)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.13->sktime>=0.7.0->evalml) (1.14.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /usr/local/lib/python3.7/dist-packages (from numba->shap>=0.36.0->evalml) (0.38.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (5.3.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (1.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.13.3)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.7.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2021.10.0->featuretools>=1.2.0->evalml) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->distributed>=2021.10.0->featuretools>=1.2.0->evalml) (2.0.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (4.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.5.1)

# %%
import evalml
from evalml import AutoMLSearch
from evalml.objectives import LeadScoring

# %%
#Using these parameters, EvalML builds a pileline that will maximize the amount of revenue per lead generated.
lead_scoring_objective = LeadScoring(
    true_positives=25,
    false_positives=-5
)

# %%
#We will be utilizing a dataset detailing a customer's job, country, state, zip, online action, the dollar amount of that action and whether they were a successful lead.

from urllib.request import urlopen
import pandas as pd
import woodwork as ww
customers_data = urlopen('https://featurelabs-static.s3.amazonaws.com/lead_scoring_ml_apps/customers.csv')
interactions_data = urlopen('https://featurelabs-static.s3.amazonaws.com/lead_scoring_ml_apps/interactions.csv')
leads_data = urlopen('https://featurelabs-static.s3.amazonaws.com/lead_scoring_ml_apps/previous_leads.csv')
customers = pd.read_csv(customers_data)
interactions = pd.read_csv(interactions_data)
leads = pd.read_csv(leads_data)

X = customers.merge(interactions, on='customer_id').merge(leads, on='customer_id')

# %%
X.head(10)
# Out:
#     customer_id      date_registered birthday  \
# 0  460429349361  2017-08-10 11:04:45      NaN
# 1  674438580580  2017-08-11 08:35:32      NaN
# 2  674438580580  2017-08-11 08:35:32      NaN
# 3  364017777045  2017-08-11 10:15:37      NaN
# 4  364017777045  2017-08-11 10:15:37      NaN
# 5  364017777045  2017-08-11 10:15:37      NaN
# 6  451481549424  2017-08-13 10:38:53      NaN
# 7  451481549424  2017-08-13 10:38:53      NaN
# 8  769958483731  2017-08-15 04:44:03      NaN
# 9  769958483731  2017-08-15 04:44:03      NaN
#
#                                         job                 phone  \
# 0                          Engineer, mining  +1-283-990-1507x7713
# 1                    Psychologist, forensic         (299)543-9962
# 2                    Psychologist, forensic         (299)543-9962
# 3                            Air cabin crew       +1-213-455-5314
# 4                            Air cabin crew       +1-213-455-5314
# 5                            Air cabin crew       +1-213-455-5314
# 6  Geographical information systems officer  001-782-926-0100x616
# 7  Geographical information systems officer  001-782-926-0100x616
# 8                    Geologist, engineering          091.946.9531
# 9                    Geologist, engineering          091.946.9531
#
#                               email country state      zip  \
# 0             christian92@gmail.com     NaN    NY  60091.0
# 1                    wwelch@lee.com      US    CA      NaN
# 2                    wwelch@lee.com      US    CA      NaN
# 3                  xjones@smith.net      US   NaN  60091.0
# 4                  xjones@smith.net      US   NaN  60091.0
# 5                  xjones@smith.net      US   NaN  60091.0
# 6  hudsonbrianna@garza-thompson.com      US    CA   2116.0
# 7  hudsonbrianna@garza-thompson.com      US    CA   2116.0
# 8                qbrooks@miller.com      US    IL   2116.0
# 9                qbrooks@miller.com      US    IL   2116.0
#
#                  owner       company            id               time_x  \
# 0  Kathleen Hawkins MD  6.185414e+11  499214050533  2017-12-04 05:21:05
# 1         John Edwards  2.114827e+11  542448787918  2018-03-13 20:10:17
# 2         John Edwards  2.114827e+11  864068700968  2018-06-30 03:20:28
# 3       Erica Anderson           NaN  632245399666  2018-04-24 19:37:30
# 4       Erica Anderson           NaN  182735438015  2018-07-20 02:50:45
# 5       Erica Anderson           NaN  591996521790  2018-08-19 08:10:40
# 6       Erica Anderson  2.591830e+11  605531090825  2018-05-13 14:41:53
# 7       Erica Anderson  2.591830e+11  599569806066  2018-06-05 05:07:17
# 8      Zachary Roberts  7.915464e+11  664288122683  2017-09-16 10:39:37
# 9      Zachary Roberts  7.915464e+11  664288122683  2017-09-16 10:39:37
#
#          action  amount       session                    referrer  \
# 0     page_view     NaN  573943098058                         NaN
# 1      purchase  135.23  680991389236              www.google.com
# 2     page_view     NaN  680991389236     https://www.twitter.com
# 3      download     NaN  894164276572  https://medium.com/article
# 4     page_view     NaN  894164276572     https://www.twitter.com
# 5  contact_form     NaN  894164276572     https://www.twitter.com
# 6     page_view     NaN  198124134215     https://www.twitter.com
# 7     page_view     NaN  868943730848  https://medium.com/article
# 8      download     NaN  689017934929  https://medium.com/article
# 9      download     NaN  689017934929  https://medium.com/article
#
#                 time_y  label
# 0  2017-10-22 05:21:05  False
# 1  2018-02-11 20:10:17   True
# 2  2018-02-11 20:10:17   True
# 3  2018-04-08 19:37:30  False
# 4  2018-04-08 19:37:30  False
# 5  2018-04-08 19:37:30  False
# 6  2018-04-29 14:41:53  False
# 7  2018-04-29 14:41:53  False
# 8  2018-11-01 04:32:58  False
# 9  2019-06-09 04:13:38  False

# %%
y = X['label']
X = X.drop(['customer_id', 'date_registered', 'birthday','phone', 'email',
            'owner', 'company', 'id', 'time_x',
            'session', 'referrer', 'time_y', 'label', 'country'], axis=1)
display(X.head())
# Out:
#                       job state      zip     action  amount
# 0        Engineer, mining    NY  60091.0  page_view     NaN
# 1  Psychologist, forensic    CA      NaN   purchase  135.23
# 2  Psychologist, forensic    CA      NaN  page_view     NaN
# 3          Air cabin crew   NaN  60091.0   download     NaN
# 4          Air cabin crew   NaN  60091.0  page_view     NaN

# %%
#We will convert our data into Woodwork data structures. Doing so enables us to have more control over the types passed to and inferred by AutoML.

# %%
X.ww.init(semantic_tags={'job': 'category'}, logical_types={'job': 'Categorical'})
y = ww.init_series(y)
X.ww
# Out:
#        Physical Type Logical Type Semantic Tag(s)
# Column
# job         category  Categorical    ['category']
# state       category  Categorical    ['category']
# zip          float64       Double     ['numeric']
# action      category  Categorical    ['category']
# amount       float64       Double     ['numeric']

# %%
#EvalML natively supports one-hot encoding and imputation so the above NaN and categorical values will be taken care of.

# %%
X_train, X_holdout, y_train, y_holdout = evalml.preprocessing.split_data(X, y, problem_type='binary', test_size=0.2, random_seed=0)

X.ww
# Out:
#        Physical Type Logical Type Semantic Tag(s)
# Column
# job         category  Categorical    ['category']
# state       category  Categorical    ['category']
# zip          float64       Double     ['numeric']
# action      category  Categorical    ['category']
# amount       float64       Double     ['numeric']

# %%
#Because the lead scoring labels are binary, we will use set the problem type to "binary". When we call .search(), the search for the best pipeline will begin.

# %%
automl = AutoMLSearch(X_train=X_train, y_train=y_train,
                      problem_type='binary',
                      objective=lead_scoring_objective,
                      additional_objectives=['auc'],
                      allowed_model_families=["catboost", "random_forest", "linear_model"],
                      max_batches=3,
                      verbose=True)

automl.search()
# Out:
# Generating pipelines to search over...
# 4 pipelines ready for search.
#
# *****************************
# * Beginning pipeline search *
# *****************************
#
# Optimizing for Lead Scoring.
# Greater score is better.
#
# Using SequentialEngine to train and score pipelines.
# Searching up to 3 batches for a total of 15 pipelines.
# Allowed model families: linear_model, linear_model, catboost, random_forest
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Best Score',
#               'type'…
# Evaluating Baseline Pipeline: Mode Baseline Binary Classification Pipeline
# Mode Baseline Binary Classification Pipeline:
# 	Starting cross validation
# 	Finished cross validation - mean Lead Scoring: 0.000
#
# *****************************
# * Evaluating Batch Number 1 *
# *****************************
# 			Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 0: Encountered an error.
# 			Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 0: All scores will be replaced with nan.
# 			Fold 0: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 0: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Elastic Net Classifier': {'penalty': 'elasticnet', 'C': 1.0, 'l1_ratio': 0.15, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'saga'}}
# 			Fold 0: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 1: Encountered an error.
# 			Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 1: All scores will be replaced with nan.
# 			Fold 1: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 1: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Elastic Net Classifier': {'penalty': 'elasticnet', 'C': 1.0, 'l1_ratio': 0.15, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'saga'}}
# 			Fold 1: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 2: Encountered an error.
# 			Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 2: All scores will be replaced with nan.
# 			Fold 2: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 2: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Elastic Net Classifier': {'penalty': 'elasticnet', 'C': 1.0, 'l1_ratio': 0.15, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'saga'}}
# 			Fold 2: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
# Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler:
# 	Starting cross validation
# 	Finished cross validation - mean Lead Scoring: nan
# 			Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 0: Encountered an error.
# 			Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 0: All scores will be replaced with nan.
# 			Fold 0: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 0: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Logistic Regression Classifier': {'penalty': 'l2', 'C': 1.0, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'lbfgs'}}
# 			Fold 0: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 1: Encountered an error.
# 			Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 1: All scores will be replaced with nan.
# 			Fold 1: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 1: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Logistic Regression Classifier': {'penalty': 'l2', 'C': 1.0, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'lbfgs'}}
# 			Fold 1: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 2: Encountered an error.
# 			Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 2: All scores will be replaced with nan.
# 			Fold 2: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 2: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Logistic Regression Classifier': {'penalty': 'l2', 'C': 1.0, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'lbfgs'}}
# 			Fold 2: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
# Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler:
# 	Starting cross validation
# 	Finished cross validation - mean Lead Scoring: nan
# 			CatBoost Classifier w/ Label Encoder + Imputer + Oversampler fold 0: Encountered an error.
# 			CatBoost Classifier w/ Label Encoder + Imputer + Oversampler fold 0: All scores will be replaced with nan.
# 			Fold 0: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 0: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'CatBoost Classifier': {'n_estimators': 10, 'eta': 0.03, 'max_depth': 6, 'bootstrap_type': None, 'silent': True, 'allow_writing_files': False, 'n_jobs': -1}}
# 			Fold 0: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			CatBoost Classifier w/ Label Encoder + Imputer + Oversampler fold 1: Encountered an error.
# 			CatBoost Classifier w/ Label Encoder + Imputer + Oversampler fold 1: All scores will be replaced with nan.
# 			Fold 1: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 1: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'CatBoost Classifier': {'n_estimators': 10, 'eta': 0.03, 'max_depth': 6, 'bootstrap_type': None, 'silent': True, 'allow_writing_files': False, 'n_jobs': -1}}
# 			Fold 1: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			CatBoost Classifier w/ Label Encoder + Imputer + Oversampler fold 2: Encountered an error.
# 			CatBoost Classifier w/ Label Encoder + Imputer + Oversampler fold 2: All scores will be replaced with nan.
# 			Fold 2: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 2: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'CatBoost Classifier': {'n_estimators': 10, 'eta': 0.03, 'max_depth': 6, 'bootstrap_type': None, 'silent': True, 'allow_writing_files': False, 'n_jobs': -1}}
# 			Fold 2: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
# CatBoost Classifier w/ Label Encoder + Imputer + Oversampler:
# 	Starting cross validation
# 	Finished cross validation - mean Lead Scoring: nan
# 			Random Forest Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 0: Encountered an error.
# 			Random Forest Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 0: All scores will be replaced with nan.
# 			Fold 0: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 0: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Random Forest Classifier': {'n_estimators': 100, 'max_depth': 6, 'n_jobs': -1}}
# 			Fold 0: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Random Forest Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 1: Encountered an error.
# 			Random Forest Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 1: All scores will be replaced with nan.
# 			Fold 1: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 1: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Random Forest Classifier': {'n_estimators': 100, 'max_depth': 6, 'n_jobs': -1}}
# 			Fold 1: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Random Forest Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 2: Encountered an error.
# 			Random Forest Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 2: All scores will be replaced with nan.
# 			Fold 2: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 2: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Random Forest Classifier': {'n_estimators': 100, 'max_depth': 6, 'n_jobs': -1}}
# 			Fold 2: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
# Random Forest Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler:
# 	Starting cross validation
# 	Finished cross validation - mean Lead Scoring: nan
# ---------------------------------------------------------------------------
# AutoMLSearchException                     Traceback (most recent call last)
# <ipython-input-24-1f5a5d0baed5> in <module>()
#       7                       verbose=True)
#       8
# ----> 9 automl.search()
#
# /usr/local/lib/python3.7/dist-packages/evalml/automl/automl_search.py in search(self, show_iteration_plot)
#     966             ):
#     967                 raise AutoMLSearchException(
# --> 968                     f"All pipelines in the current AutoML batch produced a score of np.nan on the primary objective {self.objective}."
#     969                 )
#     970
#
# AutoMLSearchException: All pipelines in the current AutoML batch produced a score of np.nan on the primary objective <evalml.objectives.lead_scoring.LeadScoring object at 0x7fe5e77dd290>.

# %%
import evalml
from evalml import AutoMLSearch
from evalml.objectives import LeadScoring
# Out:
# /usr/local/lib/python3.7/dist-packages/woodwork/__init__.py:23: FutureWarning: Woodwork may not support Python 3.7 in next non-bugfix release.
#   "Woodwork may not support Python 3.7 in next non-bugfix release.", FutureWarning
# Featuretools may not support Python 3.7 in next non-bugfix release.

# %%
lead_scoring_objective = LeadScoring(
    true_positives=1000,
    false_positives=-10)

# %%
from urllib.request import urlopen
import pandas as pd
import woodwork as ww

# %%
customers_data = urlopen('https://featurelabs-static.s3.amazonaws.com/lead_scoring_ml_apps/customers.csv')
interactions_data = urlopen('https://featurelabs-static.s3.amazonaws.com/lead_scoring_ml_apps/interactions.csv')
leads_data = urlopen('https://featurelabs-static.s3.amazonaws.com/lead_scoring_ml_apps/previous_leads.csv')

# %%
customers = pd.read_csv(customers_data)
interactions = pd.read_csv(interactions_data)
leads = pd.read_csv(leads_data)

# %%
X = customers.merge(interactions, on='customer_id').merge(leads, on='customer_id')

# %%
y = X['label']

# %%
X = X.drop(['customer_id', 'date_registered', 'birthday','phone', 'email',
            'owner', 'company', 'id', 'time_x',
            'session', 'referrer', 'time_y', 'label', 'country'],axis=1)

# %%
features_train,features_test,target_train,target_test = evalml.preprocessing.split_data(X,y,problem_type='binary',test_size=0.2)

# %%
automl = AutoMLSearch(X_train=features_train,y_train=target_train,problem_type='binary',
                     objective=lead_scoring_objective,
                     additional_objectives=['auc'],
                     max_batches=1,
                     optimize_thresholds=True)
automl.search()
# Out:
# 			Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 0: Encountered an error.
# 			Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 0: All scores will be replaced with nan.
# 			Fold 0: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 0: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Elastic Net Classifier': {'penalty': 'elasticnet', 'C': 1.0, 'l1_ratio': 0.15, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'saga'}}
# 			Fold 0: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 1: Encountered an error.
# 			Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 1: All scores will be replaced with nan.
# 			Fold 1: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 1: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Elastic Net Classifier': {'penalty': 'elasticnet', 'C': 1.0, 'l1_ratio': 0.15, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'saga'}}
# 			Fold 1: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 2: Encountered an error.
# 			Elastic Net Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 2: All scores will be replaced with nan.
# 			Fold 2: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 2: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Elastic Net Classifier': {'penalty': 'elasticnet', 'C': 1.0, 'l1_ratio': 0.15, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'saga'}}
# 			Fold 2: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 0: Encountered an error.
# 			Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 0: All scores will be replaced with nan.
# 			Fold 0: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 0: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Logistic Regression Classifier': {'penalty': 'l2', 'C': 1.0, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'lbfgs'}}
# 			Fold 0: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 1: Encountered an error.
# 			Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 1: All scores will be replaced with nan.
# 			Fold 1: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 1: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Logistic Regression Classifier': {'penalty': 'l2', 'C': 1.0, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'lbfgs'}}
# 			Fold 1: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 2: Encountered an error.
# 			Logistic Regression Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler + Standard Scaler fold 2: All scores will be replaced with nan.
# 			Fold 2: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 2: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Logistic Regression Classifier': {'penalty': 'l2', 'C': 1.0, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'lbfgs'}}
# 			Fold 2: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			XGBoost Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 0: Encountered an error.
# 			XGBoost Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 0: All scores will be replaced with nan.
# 			Fold 0: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 0: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'XGBoost Classifier': {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': -1, 'eval_metric': 'logloss'}}
# 			Fold 0: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			XGBoost Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 1: Encountered an error.
# 			XGBoost Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 1: All scores will be replaced with nan.
# 			Fold 1: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 1: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'XGBoost Classifier': {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': -1, 'eval_metric': 'logloss'}}
# 			Fold 1: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			XGBoost Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 2: Encountered an error.
# 			XGBoost Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 2: All scores will be replaced with nan.
# 			Fold 2: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 2: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'XGBoost Classifier': {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 1, 'n_estimators': 100, 'n_jobs': -1, 'eval_metric': 'logloss'}}
# 			Fold 2: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			LightGBM Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 0: Encountered an error.
# 			LightGBM Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 0: All scores will be replaced with nan.
# 			Fold 0: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 0: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'LightGBM Classifier': {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'n_estimators': 100, 'max_depth': 0, 'num_leaves': 31, 'min_child_samples': 20, 'n_jobs': -1, 'bagging_freq': 0, 'bagging_fraction': 0.9}}
# 			Fold 0: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			LightGBM Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 1: Encountered an error.
# 			LightGBM Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 1: All scores will be replaced with nan.
# 			Fold 1: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 1: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'LightGBM Classifier': {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'n_estimators': 100, 'max_depth': 0, 'num_leaves': 31, 'min_child_samples': 20, 'n_jobs': -1, 'bagging_freq': 0, 'bagging_fraction': 0.9}}
# 			Fold 1: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			LightGBM Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 2: Encountered an error.
# 			LightGBM Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 2: All scores will be replaced with nan.
# 			Fold 2: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 2: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'LightGBM Classifier': {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'n_estimators': 100, 'max_depth': 0, 'num_leaves': 31, 'min_child_samples': 20, 'n_jobs': -1, 'bagging_freq': 0, 'bagging_fraction': 0.9}}
# 			Fold 2: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			CatBoost Classifier w/ Label Encoder + Imputer + Oversampler fold 0: Encountered an error.
# 			CatBoost Classifier w/ Label Encoder + Imputer + Oversampler fold 0: All scores will be replaced with nan.
# 			Fold 0: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 0: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'CatBoost Classifier': {'n_estimators': 10, 'eta': 0.03, 'max_depth': 6, 'bootstrap_type': None, 'silent': True, 'allow_writing_files': False, 'n_jobs': -1}}
# 			Fold 0: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			CatBoost Classifier w/ Label Encoder + Imputer + Oversampler fold 1: Encountered an error.
# 			CatBoost Classifier w/ Label Encoder + Imputer + Oversampler fold 1: All scores will be replaced with nan.
# 			Fold 1: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 1: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'CatBoost Classifier': {'n_estimators': 10, 'eta': 0.03, 'max_depth': 6, 'bootstrap_type': None, 'silent': True, 'allow_writing_files': False, 'n_jobs': -1}}
# 			Fold 1: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			CatBoost Classifier w/ Label Encoder + Imputer + Oversampler fold 2: Encountered an error.
# 			CatBoost Classifier w/ Label Encoder + Imputer + Oversampler fold 2: All scores will be replaced with nan.
# 			Fold 2: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 2: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'CatBoost Classifier': {'n_estimators': 10, 'eta': 0.03, 'max_depth': 6, 'bootstrap_type': None, 'silent': True, 'allow_writing_files': False, 'n_jobs': -1}}
# 			Fold 2: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Random Forest Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 0: Encountered an error.
# 			Random Forest Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 0: All scores will be replaced with nan.
# 			Fold 0: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 0: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Random Forest Classifier': {'n_estimators': 100, 'max_depth': 6, 'n_jobs': -1}}
# 			Fold 0: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
# ...
# 			Fold 1: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Decision Tree Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 2: Encountered an error.
# 			Decision Tree Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 2: All scores will be replaced with nan.
# 			Fold 2: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 2: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Decision Tree Classifier': {'criterion': 'gini', 'max_features': 'auto', 'max_depth': 6, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0}}
# 			Fold 2: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Extra Trees Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 0: Encountered an error.
# 			Extra Trees Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 0: All scores will be replaced with nan.
# 			Fold 0: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 0: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Extra Trees Classifier': {'n_estimators': 100, 'max_features': 'auto', 'max_depth': 6, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_jobs': -1}}
# 			Fold 0: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Extra Trees Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 1: Encountered an error.
# 			Extra Trees Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 1: All scores will be replaced with nan.
# 			Fold 1: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 1: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Extra Trees Classifier': {'n_estimators': 100, 'max_features': 'auto', 'max_depth': 6, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_jobs': -1}}
# 			Fold 1: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
#
# 			Extra Trees Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 2: Encountered an error.
# 			Extra Trees Classifier w/ Label Encoder + Imputer + One Hot Encoder + Oversampler fold 2: All scores will be replaced with nan.
# 			Fold 2: Exception during automl search: 'TableSchema' object has no attribute '_get_subset_schema'
# 			Fold 2: Parameters:
# 	{'Label Encoder': {'positive_label': None}, 'Imputer': {'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'One Hot Encoder': {'top_n': 10, 'features_to_encode': None, 'categories': None, 'drop': 'if_binary', 'handle_unknown': 'ignore', 'handle_missing': 'error'}, 'Oversampler': {'sampling_ratio': 0.25, 'k_neighbors_default': 5, 'n_jobs': -1, 'sampling_ratio_dict': None}, 'Extra Trees Classifier': {'n_estimators': 100, 'max_features': 'auto', 'max_depth': 6, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_jobs': -1}}
# 			Fold 2: Traceback:
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 224, in train_and_score_pipeline
#     pipeline, X_train, y_train, automl_config, schema=False
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/automl/engine/engine_base.py", line 150, in train_pipeline
#     cv_pipeline.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/classification_pipeline.py", line 68, in fit
#     self._fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/pipeline_base.py", line 275, in _fit
#     self.component_graph.fit(X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 233, in fit
#     self._transform_features(self.compute_order, X, y, fit=True)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/component_graph.py", line 417, in _transform_features
#     output = component_instance.fit_transform(x_inputs, y_input)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/utils/base_meta.py", line 19, in _set_fit
#     return_value = method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/transformer.py", line 65, in fit_transform
#     return self.fit(X_ww, y_ww).transform(X_ww, y_ww)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 42, in _check_for_fit
#     return method(self, X, y)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/imputer.py", line 126, in transform
#     imputed = self._numeric_imputer.transform(X_numeric)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/component_base_meta.py", line 40, in _check_for_fit
#     return method(self, X)
#
#   File "/usr/local/lib/python3.7/dist-packages/evalml/pipelines/components/transformers/imputers/simple_imputer.py", line 102, in transform
#     X_t.ww.init(schema=original_schema._get_subset_schema(X_t.columns))
# ---------------------------------------------------------------------------
# AutoMLSearchException                     Traceback (most recent call last)
# <ipython-input-10-c05b865e8599> in <module>()
#       4                      max_batches=1,
#       5                      optimize_thresholds=True)
# ----> 6 automl.search()
#
# /usr/local/lib/python3.7/dist-packages/evalml/automl/automl_search.py in search(self, show_iteration_plot)
#     966             ):
#     967                 raise AutoMLSearchException(
# --> 968                     f"All pipelines in the current AutoML batch produced a score of np.nan on the primary objective {self.objective}."
#     969                 )
#     970
#
# AutoMLSearchException: All pipelines in the current AutoML batch produced a score of np.nan on the primary objective <evalml.objectives.lead_scoring.LeadScoring object at 0x7fe62217a390>.

# %%
import woodwork as ww

# X is your feature matrix
X.ww.init()

# This tells you the number of missing values 
na_count = X.ww.describe().loc['nan_count']
columns_with_missing_values = na_count[na_count > 0].index
columns_with_missing_values
# Out:
# Index(['job', 'state', 'zip', 'amount'], dtype='object')

# %%
# This tells you the columns that are natural language
nat_lang_columns = X.ww.select("NaturalLanguage").columns

nat_lang_with_nan = set(nat_lang_columns).intersection(columns_with_missing_values)
nat_lang_with_nan
# Out:
# set()

# %%
X.shape
# Out:
# (5812, 5)
